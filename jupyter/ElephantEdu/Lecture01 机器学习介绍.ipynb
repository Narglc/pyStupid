# %%
#coding:utf-8
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-4,4,100)
y = x**2
plt.plot(x,y,'r-',lw=2)
plt.show()

# %%
x = np.linspace(0,1,100)
y = x**x
plt.plot(x,y,'r-',lw=2)
plt.show()
